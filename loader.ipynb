# %%
import os
import sys
from pathlib import Path
import polars as pl
import psycopg2

# %%
"postgresql://neondb_owner:npg_H0ekaDswBgP7@ep-round-morning-axw20sxa-pooler.c-4.us-east-2.aws.neon.tech/neondb?sslmode=require&channel_binding=require"

# %%
data_folder = Path("C:/khaled/DATABRICKS/Walmart_Airflow_DBT_Project-main/Walmart_Airflow_DBT_Project-main/walmart_project/data")
print(data_folder)
list_of_files = os.listdir(data_folder)
list_of_path_files = [data_folder / file for file in list_of_files]
print(list_of_path_files)
# Out:
# C:\khaled\DATABRICKS\Walmart_Airflow_DBT_Project-main\Walmart_Airflow_DBT_Project-main\walmart_project\data
# [WindowsPath('C:/khaled/DATABRICKS/Walmart_Airflow_DBT_Project-main/Walmart_Airflow_DBT_Project-main/walmart_project/data/customers.csv'), WindowsPath('C:/khaled/DATABRICKS/Walmart_Airflow_DBT_Project-main/Walmart_Airflow_DBT_Project-main/walmart_project/data/employees.csv'), WindowsPath('C:/khaled/DATABRICKS/Walmart_Airflow_DBT_Project-main/Walmart_Airflow_DBT_Project-main/walmart_project/data/orders.csv'), WindowsPath('C:/khaled/DATABRICKS/Walmart_Airflow_DBT_Project-main/Walmart_Airflow_DBT_Project-main/walmart_project/data/order_items.csv'), WindowsPath('C:/khaled/DATABRICKS/Walmart_Airflow_DBT_Project-main/Walmart_Airflow_DBT_Project-main/walmart_project/data/products.csv'), WindowsPath('C:/khaled/DATABRICKS/Walmart_Airflow_DBT_Project-main/Walmart_Airflow_DBT_Project-main/walmart_project/data/stores.csv')]

# %%
 excel_files = [f for f in data_folder.rglob("*.csv")]
 print(excel_files)
# Out:
# [WindowsPath('C:/khaled/DATABRICKS/Walmart_Airflow_DBT_Project-main/Walmart_Airflow_DBT_Project-main/walmart_project/data/customers.csv'), WindowsPath('C:/khaled/DATABRICKS/Walmart_Airflow_DBT_Project-main/Walmart_Airflow_DBT_Project-main/walmart_project/data/employees.csv'), WindowsPath('C:/khaled/DATABRICKS/Walmart_Airflow_DBT_Project-main/Walmart_Airflow_DBT_Project-main/walmart_project/data/orders.csv'), WindowsPath('C:/khaled/DATABRICKS/Walmart_Airflow_DBT_Project-main/Walmart_Airflow_DBT_Project-main/walmart_project/data/order_items.csv'), WindowsPath('C:/khaled/DATABRICKS/Walmart_Airflow_DBT_Project-main/Walmart_Airflow_DBT_Project-main/walmart_project/data/products.csv'), WindowsPath('C:/khaled/DATABRICKS/Walmart_Airflow_DBT_Project-main/Walmart_Airflow_DBT_Project-main/walmart_project/data/stores.csv')]

# %%
for file in excel_files:
    df = pl.read_csv(file)
    print(f"DataFrame for {file.name}:")
    print(df)
    print("\n")

# %%
conn_string = "postgresql://neondb_owner:npg_H0ekaDswBgP7@ep-round-morning-axw20sxa-pooler.c-4.us-east-2.aws.neon.tech/neondb?sslmode=require&channel_binding=require"

# %%
try:
    conn = psycopg2.connect(conn_string)
    cursor = conn.cursor()
    if data_folder:
        for 



except Exception as e:
    print(f"Error connecting to the database: {e}")
    if conn:
        conn.rollback()
        conn.close()

# %%
import psycopg2
import os

# Database connection string
conn_string = "postgresql://neondb_owner:npg_H0ekaDswBgP7@ep-round-morning-axw20sxa-pooler.c-4.us-east-2.aws.neon.tech/neondb?sslmode=require&channel_binding=require"

# CSV files mapping to tables
csv_files = {
    "customers.csv": "raw.customers",
    "stores.csv": "raw.stores",
    "products.csv": "raw.products",
    "employees.csv": "raw.employees",
    "orders.csv": "raw.orders",
    "order_items.csv": "raw.order_items",
}

data_dir = "data"

try:
    # Connect to the database
    conn = psycopg2.connect(conn_string)
    cursor = conn.cursor()
    
    # Load each CSV file into its corresponding table
    for csv_file, table_name in csv_files.items():
        csv_path = os.path.join(data_dir, csv_file)

        print(f"Loading {csv_file} into {table_name}...")
        print(f"CSV Path: {csv_path}")
        
        if os.path.exists(csv_path):
            print(f"Loading {csv_file} into {table_name}...")
            
            with open(csv_path, 'r') as f:
                cursor.copy_expert(f"COPY {table_name} FROM STDIN WITH (FORMAT CSV, HEADER TRUE)", f)
            
            conn.commit()
            print(f"✓ Successfully loaded {csv_file}")
        else:
            print(f"✗ File not found: {csv_path}")
    
    cursor.close()
    conn.close()
    print("\n✓ All data loaded successfully!")
    
except Exception as e:
    print(f"Error: {e}")
    if conn:
        conn.rollback()
        conn.close()
# Out:
# Loading customers.csv into raw.customers...
# CSV Path: data\customers.csv
# Loading customers.csv into raw.customers...
# ✓ Successfully loaded customers.csv
# Loading stores.csv into raw.stores...
# CSV Path: data\stores.csv
# Loading stores.csv into raw.stores...
# ✓ Successfully loaded stores.csv
# Loading products.csv into raw.products...
# CSV Path: data\products.csv
# Loading products.csv into raw.products...
# ✓ Successfully loaded products.csv
# Loading employees.csv into raw.employees...
# CSV Path: data\employees.csv
# Loading employees.csv into raw.employees...
# ✓ Successfully loaded employees.csv
# Loading orders.csv into raw.orders...
# CSV Path: data\orders.csv
# Loading orders.csv into raw.orders...
# ✓ Successfully loaded orders.csv
# Loading order_items.csv into raw.order_items...
# CSV Path: data\order_items.csv
# Loading order_items.csv into raw.order_items...
# ✓ Successfully loaded order_items.csv
#
# ✓ All data loaded successfully!
